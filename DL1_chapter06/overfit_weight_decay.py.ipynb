# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11, test acc:0.1121
# epoch:1, train acc:0.13333333333333333, test acc:0.1231
# epoch:2, train acc:0.13666666666666666, test acc:0.1344
# epoch:3, train acc:0.15666666666666668, test acc:0.1415
# epoch:4, train acc:0.17, test acc:0.1479
# epoch:5, train acc:0.17, test acc:0.1506
# epoch:6, train acc:0.20333333333333334, test acc:0.1526
# epoch:7, train acc:0.21, test acc:0.1581
# epoch:8, train acc:0.23333333333333334, test acc:0.1641
# epoch:9, train acc:0.2833333333333333, test acc:0.175
# epoch:10, train acc:0.27666666666666667, test acc:0.1846
# epoch:11, train acc:0.32, test acc:0.203
# epoch:12, train acc:0.35333333333333333, test acc:0.2132
# epoch:13, train acc:0.38, test acc:0.2332
# epoch:14, train acc:0.41, test acc:0.2498
# epoch:15, train acc:0.44, test acc:0.2652
# epoch:16, train acc:0.46, test acc:0.2844
# epoch:17, train acc:0.4633333333333333, test acc:0.2996
# epoch:18, train acc:0.48333333333333334, test acc:0.3097
# epoch:19, train acc:0.5166666666666667, test acc:0.3431
# epoch:20, train acc:0.54, test acc:0.3629
# epoch:21, train acc:0.5533333333333333, test acc:0.3756
# epoch:22, train acc:0.5633333333333334, test acc:0.3884
# epoch:23, train acc:0.58, test acc:0.397
# epoch:24, train acc:0.5833333333333334, test acc:0.4089
# epoch:25, train acc:0.59, test acc:0.4156
# epoch:26, train acc:0.58, test acc:0.4187
# epoch:27, train acc:0.6, test acc:0.4222
# epoch:28, train acc:0.59, test acc:0.4311
# epoch:29, train acc:0.6033333333333334, test acc:0.44
# epoch:30, train acc:0.6, test acc:0.4468
# epoch:31, train acc:0.6033333333333334, test acc:0.4558
# epoch:32, train acc:0.6066666666666667, test acc:0.454
# epoch:33, train acc:0.6166666666666667, test acc:0.4606
# epoch:34, train acc:0.6266666666666667, test acc:0.4663
# epoch:35, train acc:0.6233333333333333, test acc:0.4667
# epoch:36, train acc:0.6433333333333333, test acc:0.475
# epoch:37, train acc:0.63, test acc:0.4829
# epoch:38, train acc:0.64, test acc:0.4832
# epoch:39, train acc:0.6333333333333333, test acc:0.4831
# epoch:40, train acc:0.6466666666666666, test acc:0.4943
# epoch:41, train acc:0.6666666666666666, test acc:0.4996
# epoch:42, train acc:0.6733333333333333, test acc:0.509
# epoch:43, train acc:0.6766666666666666, test acc:0.5062
# epoch:44, train acc:0.67, test acc:0.5056
# epoch:45, train acc:0.6766666666666666, test acc:0.5145
# epoch:46, train acc:0.68, test acc:0.5177
# epoch:47, train acc:0.6866666666666666, test acc:0.525
# epoch:48, train acc:0.7066666666666667, test acc:0.532
# epoch:49, train acc:0.7, test acc:0.5371
# epoch:50, train acc:0.72, test acc:0.5461
# epoch:51, train acc:0.7066666666666667, test acc:0.5373
# epoch:52, train acc:0.74, test acc:0.5508
# epoch:53, train acc:0.7433333333333333, test acc:0.5553
# epoch:54, train acc:0.7366666666666667, test acc:0.5562
# epoch:55, train acc:0.75, test acc:0.5587
# epoch:56, train acc:0.7333333333333333, test acc:0.564
# epoch:57, train acc:0.74, test acc:0.561
# epoch:58, train acc:0.77, test acc:0.5776
# epoch:59, train acc:0.76, test acc:0.5812
# epoch:60, train acc:0.7866666666666666, test acc:0.5941
# epoch:61, train acc:0.7933333333333333, test acc:0.5961
# epoch:62, train acc:0.79, test acc:0.5926
# epoch:63, train acc:0.7966666666666666, test acc:0.591
# epoch:64, train acc:0.7866666666666666, test acc:0.5998
# epoch:65, train acc:0.8, test acc:0.6149
# epoch:66, train acc:0.8066666666666666, test acc:0.6169
# epoch:67, train acc:0.79, test acc:0.6167
# epoch:68, train acc:0.8, test acc:0.6208
# epoch:69, train acc:0.8033333333333333, test acc:0.6284
# epoch:70, train acc:0.81, test acc:0.6222
# epoch:71, train acc:0.8133333333333334, test acc:0.6127
# epoch:72, train acc:0.8133333333333334, test acc:0.608
# epoch:73, train acc:0.8166666666666667, test acc:0.6229
# epoch:74, train acc:0.8066666666666666, test acc:0.6308
# epoch:75, train acc:0.8166666666666667, test acc:0.6325
# epoch:76, train acc:0.82, test acc:0.6261
# epoch:77, train acc:0.8166666666666667, test acc:0.6405
# epoch:78, train acc:0.8233333333333334, test acc:0.6293
# epoch:79, train acc:0.8233333333333334, test acc:0.6262
# epoch:80, train acc:0.8233333333333334, test acc:0.6167
# epoch:81, train acc:0.83, test acc:0.636
# epoch:82, train acc:0.8233333333333334, test acc:0.644
# epoch:83, train acc:0.83, test acc:0.6468
# epoch:84, train acc:0.8366666666666667, test acc:0.6468
# epoch:85, train acc:0.8333333333333334, test acc:0.6423
# epoch:86, train acc:0.84, test acc:0.6573
# epoch:87, train acc:0.8266666666666667, test acc:0.6575
# epoch:88, train acc:0.8333333333333334, test acc:0.6532
# epoch:89, train acc:0.8333333333333334, test acc:0.659
# epoch:90, train acc:0.83, test acc:0.6636
# epoch:91, train acc:0.85, test acc:0.6577
# epoch:92, train acc:0.8366666666666667, test acc:0.6617
# epoch:93, train acc:0.8366666666666667, test acc:0.6507
# epoch:94, train acc:0.8433333333333334, test acc:0.6594
# epoch:95, train acc:0.84, test acc:0.6582
# epoch:96, train acc:0.8466666666666667, test acc:0.665
# epoch:97, train acc:0.8666666666666667, test acc:0.6676
# epoch:98, train acc:0.85, test acc:0.6608
# epoch:99, train acc:0.86, test acc:0.6696
# epoch:100, train acc:0.8533333333333334, test acc:0.6691
# epoch:101, train acc:0.8466666666666667, test acc:0.6681
# epoch:102, train acc:0.8566666666666667, test acc:0.67
# epoch:103, train acc:0.8466666666666667, test acc:0.6547
# epoch:104, train acc:0.8633333333333333, test acc:0.6594
# epoch:105, train acc:0.85, test acc:0.6605
# epoch:106, train acc:0.8533333333333334, test acc:0.6629
# epoch:107, train acc:0.86, test acc:0.6697
# epoch:108, train acc:0.8533333333333334, test acc:0.6653
# epoch:109, train acc:0.8633333333333333, test acc:0.6736
# epoch:110, train acc:0.8666666666666667, test acc:0.6678
# epoch:111, train acc:0.8633333333333333, test acc:0.6695
# epoch:112, train acc:0.8633333333333333, test acc:0.6576
# epoch:113, train acc:0.8566666666666667, test acc:0.6679
# epoch:114, train acc:0.8733333333333333, test acc:0.6726
# epoch:115, train acc:0.8566666666666667, test acc:0.6733
# epoch:116, train acc:0.86, test acc:0.6712
# epoch:117, train acc:0.8633333333333333, test acc:0.6802
# epoch:118, train acc:0.86, test acc:0.6785
# epoch:119, train acc:0.87, test acc:0.6767
# epoch:120, train acc:0.8833333333333333, test acc:0.6732
# epoch:121, train acc:0.8666666666666667, test acc:0.67
# epoch:122, train acc:0.8666666666666667, test acc:0.679
# epoch:123, train acc:0.8666666666666667, test acc:0.6743
# epoch:124, train acc:0.88, test acc:0.6775
# epoch:125, train acc:0.87, test acc:0.6811
# epoch:126, train acc:0.8733333333333333, test acc:0.68
# epoch:127, train acc:0.8666666666666667, test acc:0.6804
# epoch:128, train acc:0.8833333333333333, test acc:0.6809
# epoch:129, train acc:0.8766666666666667, test acc:0.6874
# epoch:130, train acc:0.88, test acc:0.6754
# epoch:131, train acc:0.8766666666666667, test acc:0.6793
# epoch:132, train acc:0.8733333333333333, test acc:0.6786
# epoch:133, train acc:0.88, test acc:0.6823
# epoch:134, train acc:0.8733333333333333, test acc:0.6859
# epoch:135, train acc:0.88, test acc:0.685
# epoch:136, train acc:0.8866666666666667, test acc:0.6748
# epoch:137, train acc:0.88, test acc:0.6846
# epoch:138, train acc:0.8933333333333333, test acc:0.6837
# epoch:139, train acc:0.89, test acc:0.6885
# epoch:140, train acc:0.8866666666666667, test acc:0.6875
# epoch:141, train acc:0.8933333333333333, test acc:0.6829
# epoch:142, train acc:0.8933333333333333, test acc:0.6844
# epoch:143, train acc:0.9, test acc:0.6856
# epoch:144, train acc:0.89, test acc:0.6837
# epoch:145, train acc:0.8933333333333333, test acc:0.6854
# epoch:146, train acc:0.9066666666666666, test acc:0.6882
# epoch:147, train acc:0.8866666666666667, test acc:0.6911
# epoch:148, train acc:0.9, test acc:0.6909
# epoch:149, train acc:0.8966666666666666, test acc:0.6915
# epoch:150, train acc:0.8966666666666666, test acc:0.691
# epoch:151, train acc:0.9066666666666666, test acc:0.6942
# epoch:152, train acc:0.8933333333333333, test acc:0.6923
# epoch:153, train acc:0.8966666666666666, test acc:0.6913
# epoch:154, train acc:0.8933333333333333, test acc:0.6828
# epoch:155, train acc:0.8966666666666666, test acc:0.6906
# epoch:156, train acc:0.89, test acc:0.6863
# epoch:157, train acc:0.9, test acc:0.6892
# epoch:158, train acc:0.8966666666666666, test acc:0.6931
# epoch:159, train acc:0.9033333333333333, test acc:0.6863
# epoch:160, train acc:0.9033333333333333, test acc:0.6916
# epoch:161, train acc:0.89, test acc:0.6827
# epoch:162, train acc:0.8933333333333333, test acc:0.6867
# epoch:163, train acc:0.89, test acc:0.6921
# epoch:164, train acc:0.8966666666666666, test acc:0.6926
# epoch:165, train acc:0.9033333333333333, test acc:0.6929
# epoch:166, train acc:0.8933333333333333, test acc:0.6935
# epoch:167, train acc:0.8966666666666666, test acc:0.6923
# epoch:168, train acc:0.8966666666666666, test acc:0.6916
# epoch:169, train acc:0.8933333333333333, test acc:0.6955
# epoch:170, train acc:0.8966666666666666, test acc:0.6992
# epoch:171, train acc:0.9033333333333333, test acc:0.7013
# epoch:172, train acc:0.8933333333333333, test acc:0.6994
# epoch:173, train acc:0.8933333333333333, test acc:0.7012
# epoch:174, train acc:0.9, test acc:0.7011
# epoch:175, train acc:0.8866666666666667, test acc:0.697
# epoch:176, train acc:0.8933333333333333, test acc:0.6917
# epoch:177, train acc:0.9066666666666666, test acc:0.6931
# epoch:178, train acc:0.9033333333333333, test acc:0.6989
# epoch:179, train acc:0.9066666666666666, test acc:0.697
# epoch:180, train acc:0.8966666666666666, test acc:0.7031
# epoch:181, train acc:0.8933333333333333, test acc:0.7008
# epoch:182, train acc:0.9033333333333333, test acc:0.6978
# epoch:183, train acc:0.9, test acc:0.6906
# epoch:184, train acc:0.9, test acc:0.6949
# epoch:185, train acc:0.8966666666666666, test acc:0.6938
# epoch:186, train acc:0.9033333333333333, test acc:0.6875
# epoch:187, train acc:0.9066666666666666, test acc:0.6978
# epoch:188, train acc:0.8966666666666666, test acc:0.6991
# epoch:189, train acc:0.9066666666666666, test acc:0.6923
# epoch:190, train acc:0.8966666666666666, test acc:0.7042
# epoch:191, train acc:0.9, test acc:0.6996
# epoch:192, train acc:0.9, test acc:0.6985
# epoch:193, train acc:0.9033333333333333, test acc:0.6985
# epoch:194, train acc:0.91, test acc:0.7013
# epoch:195, train acc:0.9, test acc:0.6971
# epoch:196, train acc:0.9033333333333333, test acc:0.6914
# epoch:197, train acc:0.91, test acc:0.7045
# epoch:198, train acc:0.9066666666666666, test acc:0.7045
# epoch:199, train acc:0.9066666666666666, test acc:0.6995
# epoch:200, train acc:0.9033333333333333, test acc:0.7031
